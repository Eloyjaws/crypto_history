# %%
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
doge = pd.read_csv('DOGE.csv')

# %%
doge
# Out:
#             date      open      high       low     close        volume  \
# 0     2013-12-16  0.000299  0.000866  0.000150  0.000205  0.000000e+00
# 1     2013-12-17  0.000207  0.000289  0.000116  0.000269  0.000000e+00
# 2     2013-12-18  0.000267  0.000362  0.000205  0.000362  0.000000e+00
# 3     2013-12-19  0.000395  0.001520  0.000328  0.001162  0.000000e+00
# 4     2013-12-20  0.001143  0.001143  0.000662  0.000704  0.000000e+00
# ...          ...       ...       ...       ...       ...           ...
# 2606  2021-02-03  0.031493  0.039105  0.031146  0.037120  3.146857e+09
# 2607  2021-02-04  0.037226  0.057869  0.035945  0.053289  1.304084e+10
# 2608  2021-02-05  0.053043  0.053740  0.043540  0.046935  6.136160e+09
# 2609  2021-02-06  0.046931  0.058308  0.044904  0.057595  5.946101e+09
# 2610  2021-02-07  0.057502  0.084357  0.054239  0.078782  1.426102e+10
#
#         market_cap
# 0     1.509085e+06
# 1     2.169688e+06
# 2     3.188943e+06
# 3     1.115034e+07
# ...

# %%
doge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2611 entries, 0 to 2610
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        2611 non-null   object
#  1   open        2611 non-null   float64
#  2   high        2611 non-null   float64
#  3   low         2611 non-null   float64
#  4   close       2611 non-null   float64
#  5   volume      2611 non-null   float64
#  6   market_cap  2611 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 142.9+ KB

# %%
fig, ax = plt.subplots()

ax.grid(True)

doge["date"] = pd.to_datetime(doge["date"])

ax.plot(doge.date, doge.close, color="red")
# ax.plot(x, new_y)
fig.suptitle(None)

ax.set_title("DOGECOIN'S PRICE HISTORY (2013 - 2021)")
ax.set_ylabel("Daily closing value (USD)")
ax.set_xlabel("Time")

fig.savefig("doge.png", dpi=300)

# %%
doge2021 = doge[doge['date'].dt.year == 2021]

fig, ax = plt.subplots()

ax.grid(True)
ax.plot(doge2021.date, doge2021.close, color="red")
# ax.plot(x, new_y)
fig.suptitle(None)

ax.set_title("DOGECOIN'S PRICE HISTORY (2021)")
ax.set_ylabel("Daily closing value (USD)")
ax.set_xlabel("Time")

for tick in ax.get_xticklabels():
    tick.set_rotation(45)

fig.savefig("doge2021.png", dpi=300)

# %%
elon_influence_dates = pd.to_datetime(['2021-02-04', '2021-02-08'])
# elon_influence_dates = pd.to_datetime(['2020-12-2']) #  Another notable date is Dec 20, 2020

dogeFebruary = doge2021[doge2021['date'].dt.month == 2]

fig, ax = plt.subplots()

ax.grid(True)
value = ax.plot(dogeFebruary.date, dogeFebruary.close, color="red")
fig.suptitle(None)

ax.set_title("DOGECOIN'S PRICE HISTORY (FEB, 2021)")
ax.set_ylabel("Daily closing value (USD)")
ax.set_xlabel("Time")

for influence in elon_influence_dates:
    ax.vlines(influence, 0.02, 0.08, linestyles="-.", color="yellow")

ax.legend(['Coin Value', 'Day of Elon\'s viral influence'], loc=4)

for tick in ax.get_xticklabels():
    tick.set_rotation(45)

fig.savefig("doge_Feb_2021.png", dpi=300)
